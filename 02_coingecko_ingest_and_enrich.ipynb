# %% [markdown]
# ### Ingest into bronze table (append only)

# %%
# %sql
CREATE OR REFRESH STREAMING LIVE TABLE coins_bronze TBLPROPERTIES (
  'delta.minReaderVersion' = '2',
  'delta.minWriterVersion' = '5',
  'delta.columnMapping.mode' = 'name'
) AS
SELECT *, input_file_name() file_name FROM cloud_files("/coingecko/", "json");
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>message</th></tr></thead><tbody><tr><td>This Delta Live Tables query is syntactically valid, but you must create a pipeline in order to define and populate your table.</td></tr></tbody></table></div>

# %%
# %sql
--DROP TABLE vijay_stock_portfolio.coins_bronze;
--SELECT * FROM vijay_stock_portfolio.coins_bronze;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>#</th><th>1h</th><th>24h</th><th>24h Volume</th><th>7d</th><th>Coin</th><th>Last 7 Days</th><th>Mkt Cap</th><th>Price</th><th>Unnamed: 0</th><th>Unnamed: 3</th><th>as_of</th><th>_rescued_data</th><th>file_name</th></tr></thead><tbody><tr><td>1</td><td>-0.4%</td><td>-4.8%</td><td>$28,629,302,351</td><td>-5.9%</td><td>Bitcoin  BTC  BTC</td><td>null</td><td>$569,199,403,059</td><td>$29,860.37</td><td>null</td><td>null</td><td>2022-06-07T16:17:40.850317</td><td>null</td><td>/coingecko/2022-06-07T16:17:41.041920.json</td></tr><tr><td>2</td><td>-0.5%</td><td>-5.0%</td><td>$19,216,288,548</td><td>-10.9%</td><td>Ethereum  ETH  ETH</td><td>null</td><td>$215,396,846,237</td><td>$1,778.35</td><td>null</td><td>null</td><td>2022-06-07T16:17:40.850317</td><td>null</td><td>/coingecko/2022-06-07T16:17:41.041920.json</td></tr><tr><td>3</td><td>-0.0%</td><td>0.1%</td><td>$41,752,045,858</td><td>0.0%</td><td>Tether  USDT  USDT</td><td>null</td><td>$72,435,546,060</td><td>$1.00</td><td>null</td><td>null</td><td>2022-06-07T16:17:40.850317</td><td>null</td><td>/coingecko/2022-06-07T16:17:41.041920.json</td></tr><tr><td>4</td><td>-0.1%</td><td>-0.0%</td><td>$4,756,673,884</td><td>-0.0%</td><td>USD Coin  USDC  USDC</td><td>null</td><td>$53,847,568,247</td><td>$1.00</td><td>null</td><td>null</td><td>2022-06-07T16:17:40.850317</td><td>null</td><td>/coingecko/2022-06-07T16:17:41.041920.json</td></tr><tr><td>5</td><td>-0.3%</td><td>-6.5%</td><td>$1,722,247,201</td><td>-12.3%</td><td>BNB  BNB  BNB</td><td>null</td><td>$46,125,900,409</td><td>$282.56</td><td>null</td><td>null</td><td>2022-06-07T16:17:40.850317</td><td>null</td><td>/coingecko/2022-06-07T16:17:41.041920.json</td></tr><tr><td>6</td><td>-1.5%</td><td>1.7%</td><td>$1,146,182,432</td><td>7.6%</td><td>Cardano  ADA  ADA</td><td>null</td><td>$20,799,712,062</td><td>$0.614013</td><td>null</td><td>null</td><td>2022-06-07T16:17:40.850317</td><td>null</td><td>/coingecko/2022-06-07T16:17:41.041920.json</td></tr><tr><td>7</td><td>0.1%</td><td>-1.3%</td><td>$1,306,152,321</td><td>-5.6%</td><td>XRP  XRP  XRP</td><td>null</td><td>$19,099,846,360</td><td>$0.395076</td><td>null</td><td>null</td><td>2022-06-07T16:17:40.850317</td><td>null</td><td>/coingecko/2022-06-07T16:17:41.041920.json</td></tr><tr><td>8</td><td>-0.3%</td><td>0.3%</td><td>$4,862,779,154</td><td>0.3%</td><td>Binance USD  BUSD  BUSD</td><td>null</td><td>$18,187,490,185</td><td>$1.00</td><td>null</td><td>null</td><td>2022-06-07T16:17:40.850317</td><td>null</td><td>/coingecko/2022-06-07T16:17:41.041920.json</td></tr><tr><td>9</td><td>-1.2%</td><td>-7.7%</td><td>$1,897,268,642</td><td>-17.5%</td><td>Solana  SOL  SOL</td><td>null</td><td>$13,284,076,338</td><td>$38.94</td><td>null</td><td>null</td><td>2022-06-07T16:17:40.850317</td><td>null</td><td>/coingecko/2022-06-07T16:17:41.041920.json</td></tr><tr><td>10</td><td>0.1%</td><td>-2.9%</td><td>$405,911,893</td><td>-8.5%</td><td>Dogecoin  DOGE  DOGE</td><td>null</td><td>$10,673,075,686</td><td>$0.080482317306</td><td>null</td><td>null</td><td>2022-06-07T16:17:40.850317</td><td>null</td><td>/coingecko/2022-06-07T16:17:41.041920.json</td></tr><tr><td>11</td><td>-1.0%</td><td>-5.7%</td><td>$320,730,981</td><td>-13.1%</td><td>Polkadot  DOT  DOT</td><td>null</td><td>$10,181,407,122</td><td>$9.09</td><td>null</td><td>null</td><td>2022-06-07T16:17:40.850317</td><td>null</td><td>/coingecko/2022-06-07T16:17:41.041920.json</td></tr><tr><td>12</td><td>-0.4%</td><td>-4.9%</td><td>$373,702,021</td><td>-5.8%</td><td>Wrapped Bitcoin  WBTC  WBTC</td><td>null</td><td>$8,154,074,053</td><td>$29,846.02</td><td>null</td><td>null</td><td>2022-06-07T16:17:40.850317</td><td>null</td><td>/coingecko/2022-06-07T16:17:41.041920.json</td></tr><tr><td>13</td><td>-1.2%</td><td>-1.8%</td><td>$855,745,670</td><td>-3.0%</td><td>TRON  TRX  TRX</td><td>null</td><td>$7,515,463,889</td><td>$0.080839192210</td><td>nu ...

# %%
# %sql
-- CREATE OR REPLACE FUNCTION clean_up (numeric_string STRING)
-- RETURNS DOUBLE
-- RETURN double(replace(replace(replace(numeric_string, '$', ''), ',', ''), '%', ''));
--DESCRIBE FUNCTION EXTENDED clean_up;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>function_desc</th></tr></thead><tbody><tr><td>Function:      default.clean_up</td></tr><tr><td>Type:          SCALAR</td></tr><tr><td>Input:         numeric_string STRING</td></tr><tr><td>Returns:       DOUBLE</td></tr><tr><td>Deterministic: true</td></tr><tr><td>Data Access:   CONTAINS SQL</td></tr><tr><td>Configs:       spark.sql.hive.convertCTAS=true</td></tr><tr><td>               spark.sql.legacy.createHiveTableByDefault=false</td></tr><tr><td>               spark.sql.parquet.compression.codec=snappy</td></tr><tr><td>               spark.sql.sources.commitProtocolClass=com.databricks.sql.transaction.directory.DirectoryAtomicCommitProtocol</td></tr><tr><td>               spark.sql.sources.default=delta</td></tr><tr><td>               spark.sql.streaming.stopTimeout=15s</td></tr><tr><td>Owner:         root</td></tr><tr><td>Create Time:   Tue Jun 07 17:26:38 UTC 2022</td></tr><tr><td>Body:          double(replace(replace(replace(numeric_string, '$', ''), ',', ''), '%', ''))</td></tr></tbody></table></div>

# %% [markdown]
# ### Enrich into silver table
#
# Clean up data types, keep only latest version

# %%
# %sql
CREATE OR REPLACE LIVE TABLE coins_silver AS
SELECT `#` rank, Coin coin, clean_up(Price) price, clean_up(`Mkt Cap`) mkt_cap, clean_up(`24h Volume`) volume_24h, 
clean_up(`1h`) change_1h, clean_up(`24h`) change_24h, clean_up(`7d`) change_7d, as_of
FROM live.coins_bronze
WHERE as_of = (SELECT MAX(as_of) FROM live.coins_bronze);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>message</th></tr></thead><tbody><tr><td>This Delta Live Tables query is syntactically valid, but you must create a pipeline in order to define and populate your table.</td></tr></tbody></table></div>
